# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# #### pandas main two part Dataframe and Series

# %%
df=pd.read_csv("matches.csv")

# %%
df.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'result', 'dl_applied', 'winner', 'win_by_runs',
#        'win_by_wickets', 'player_of_match', 'venue', 'umpire1', 'umpire2',
#        'umpire3'],
#       dtype='object')

# %%
df.head(5)
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
df.shape
# Out:
# (636, 18)

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 636 entries, 0 to 635
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               636 non-null    int64
#  1   season           636 non-null    int64
#  2   city             629 non-null    object
#  3   date             636 non-null    object
#  4   team1            636 non-null    object
#  5   team2            636 non-null    object
#  6   toss_winner      636 non-null    object
#  7   toss_decision    636 non-null    object
#  8   result           636 non-null    object
#  9   dl_applied       636 non-null    int64
#  10  winner           633 non-null    object
#  11  win_by_runs      636 non-null    int64
#  12  win_by_wickets   636 non-null    int64
#  13  player_of_match  633 non-null    object
#  14  venue            636 non-null    object
#  15  umpire1          635 non-null    object
#  16  umpire2          635 non-null    object
# ...

# %%
df.tail(1)
# Out:
#       id  season       city        date                team1  \
# 635  636    2016  Bangalore  2016-05-29  Sunrisers Hyderabad
#
#                            team2          toss_winner toss_decision  result  \
# 635  Royal Challengers Bangalore  Sunrisers Hyderabad           bat  normal
#
#      dl_applied               winner  win_by_runs  win_by_wickets  \
# 635           0  Sunrisers Hyderabad            8               0
#
#     player_of_match                  venue          umpire1       umpire2  \
# 635     BCJ Cutting  M Chinnaswamy Stadium  HDPK Dharmasena  BNJ Oxenford
#
#      umpire3
# 635      NaN

# %% [markdown]
# ##### Describe used for numerical columns

# %%
df.describe()
# Out:
#                id       season  dl_applied  win_by_runs  win_by_wickets  \
# count  636.000000   636.000000  636.000000   636.000000      636.000000
# mean   318.500000  2012.490566    0.025157    13.682390        3.372642
# std    183.741666     2.773026    0.156726    23.908877        3.420338
# min      1.000000  2008.000000    0.000000     0.000000        0.000000
# 25%    159.750000  2010.000000    0.000000     0.000000        0.000000
# 50%    318.500000  2012.000000    0.000000     0.000000        4.000000
# 75%    477.250000  2015.000000    0.000000    20.000000        7.000000
# max    636.000000  2017.000000    1.000000   146.000000       10.000000
#
#        umpire3
# count      0.0
# mean       NaN
# std        NaN
# min        NaN
# 25%        NaN
# 50%        NaN
# 75%        NaN
# max        NaN

# %%
#test_column=df[['season','umpire3']] ### Assigned to the variable to the dataframe value
test_column=df[['season','umpire3']]
#test_column
# select three rows and two columns
df.loc[1:3, ['season', 'umpire3']] ## multiple columns end method by loc
# and second to fourth column
df[df.columns[1:4]] ## muliple columns via columns
# Out:
#      season       city        date
# 0      2017  Hyderabad  2017-04-05
# 1      2017       Pune  2017-04-06
# 2      2017     Rajkot  2017-04-07
# 3      2017     Indore  2017-04-08
# 4      2017  Bangalore  2017-04-08
# ..      ...        ...         ...
# 631    2016     Raipur  2016-05-22
# 632    2016  Bangalore  2016-05-24
# 633    2016      Delhi  2016-05-25
# 634    2016      Delhi  2016-05-27
# 635    2016  Bangalore  2016-05-29
#
# [636 rows x 3 columns]

# %% [markdown]
# #### how to fetch row and column in dataframe.

# %%
df['winner']  ## for single columns or df.winner both series
type(df['winner'])
df.winner
# Out:
# 0              Sunrisers Hyderabad
# 1           Rising Pune Supergiant
# 2            Kolkata Knight Riders
# 3                  Kings XI Punjab
# 4      Royal Challengers Bangalore
#                   ...
# 631    Royal Challengers Bangalore
# 632    Royal Challengers Bangalore
# 633            Sunrisers Hyderabad
# 634            Sunrisers Hyderabad
# 635            Sunrisers Hyderabad
# Name: winner, Length: 636, dtype: object

# %%
df[['winner','season','date']] ## for multiple column
# Out:
#                           winner  season        date
# 0            Sunrisers Hyderabad    2017  2017-04-05
# 1         Rising Pune Supergiant    2017  2017-04-06
# 2          Kolkata Knight Riders    2017  2017-04-07
# 3                Kings XI Punjab    2017  2017-04-08
# 4    Royal Challengers Bangalore    2017  2017-04-08
# ..                           ...     ...         ...
# 631  Royal Challengers Bangalore    2016  2016-05-22
# 632  Royal Challengers Bangalore    2016  2016-05-24
# 633          Sunrisers Hyderabad    2016  2016-05-25
# 634          Sunrisers Hyderabad    2016  2016-05-27
# 635          Sunrisers Hyderabad    2016  2016-05-29
#
# [636 rows x 3 columns]

# %%
#### iloc
df.iloc[2] ## series based data
df.iloc[1:2] ## dataframe 
df.iloc[0:5:2]  ## row with step exluding 5th with step 2
df.iloc[1:2,0:1]
# Out:
#    id
# 1   2

# %%
df.iloc[[1,2,5]] ## row no given into the list based
# Out:
#    id  season       city        date           team1                   team2  \
# 1   2    2017       Pune  2017-04-06  Mumbai Indians  Rising Pune Supergiant
# 2   3    2017     Rajkot  2017-04-07   Gujarat Lions   Kolkata Knight Riders
# 5   6    2017  Hyderabad  2017-04-09   Gujarat Lions     Sunrisers Hyderabad
#
#               toss_winner toss_decision  result  dl_applied  \
# 1  Rising Pune Supergiant         field  normal           0
# 2   Kolkata Knight Riders         field  normal           0
# 5     Sunrisers Hyderabad         field  normal           0
#
#                    winner  win_by_runs  win_by_wickets player_of_match  \
# 1  Rising Pune Supergiant            0               7       SPD Smith
# 2   Kolkata Knight Riders            0              10         CA Lynn
# 5     Sunrisers Hyderabad            0               9     Rashid Khan
#
#                                        venue         umpire1    umpire2  \
# ...

# %%
df.iloc[:,[4,5,10]]
# Out:
#                            team1                        team2  \
# 0            Sunrisers Hyderabad  Royal Challengers Bangalore
# 1                 Mumbai Indians       Rising Pune Supergiant
# 2                  Gujarat Lions        Kolkata Knight Riders
# 3         Rising Pune Supergiant              Kings XI Punjab
# 4    Royal Challengers Bangalore             Delhi Daredevils
# ..                           ...                          ...
# 631             Delhi Daredevils  Royal Challengers Bangalore
# 632                Gujarat Lions  Royal Challengers Bangalore
# 633          Sunrisers Hyderabad        Kolkata Knight Riders
# 634                Gujarat Lions          Sunrisers Hyderabad
# 635          Sunrisers Hyderabad  Royal Challengers Bangalore
#
#                           winner
# 0            Sunrisers Hyderabad
# 1         Rising Pune Supergiant
# 2          Kolkata Knight Riders
# 3                Kings XI Punjab
# 4    Royal Challengers Bangalore
# ...

# %%
df.loc[0] ## Zeroth row verify
# Out:
# id                                                         1
# season                                                  2017
# city                                               Hyderabad
# date                                              2017-04-05
# team1                                    Sunrisers Hyderabad
# team2                            Royal Challengers Bangalore
# toss_winner                      Royal Challengers Bangalore
# toss_decision                                          field
# result                                                normal
# dl_applied                                                 0
# winner                                   Sunrisers Hyderabad
# win_by_runs                                               35
# win_by_wickets                                             0
# player_of_match                                 Yuvraj Singh
# venue              Rajiv Gandhi International Stadium, Uppal
# ...

# %%
# df.loc[rows, columns]
# row 1, all columns
df.loc[0, :]
# Out:
# id                                                         1
# season                                                  2017
# city                                               Hyderabad
# date                                              2017-04-05
# team1                                    Sunrisers Hyderabad
# team2                            Royal Challengers Bangalore
# toss_winner                      Royal Challengers Bangalore
# toss_decision                                          field
# result                                                normal
# dl_applied                                                 0
# winner                                   Sunrisers Hyderabad
# win_by_runs                                               35
# win_by_wickets                                             0
# player_of_match                                 Yuvraj Singh
# venue              Rajiv Gandhi International Stadium, Uppal
# ...

# %%
# slice inclusive of the ending index.
# select all rows 
# select first two column
df.iloc[:, 0:2] ## excluding 2nd columns
# iloc[row slicing, column slicing]
df.iloc [0:2, 1:3]
df.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'result', 'dl_applied', 'winner', 'win_by_runs',
#        'win_by_wickets', 'player_of_match', 'venue', 'umpire1', 'umpire2',
#        'umpire3'],
#       dtype='object')

# %%
df.iloc [0:2, 1:3]
# Out:
#    season       city
# 0    2017  Hyderabad
# 1    2017       Pune

# %%
df.loc[100]
# Out:
# id                                         101
# season                                    2008
# city                                    Jaipur
# date                                2008-05-17
# team1                         Rajasthan Royals
# team2              Royal Challengers Bangalore
# toss_winner        Royal Challengers Bangalore
# toss_decision                            field
# result                                  normal
# dl_applied                                   0
# winner                        Rajasthan Royals
# win_by_runs                                 65
# win_by_wickets                               0
# player_of_match                       GC Smith
# venue                   Sawai Mansingh Stadium
# umpire1                              BF Bowden
# umpire2                             SL Shastri
# umpire3                                    NaN
# Name: 100, dtype: object

# %%
df.tail(n=1)
# Out:
#       id  season       city        date                team1  \
# 635  636    2016  Bangalore  2016-05-29  Sunrisers Hyderabad
#
#                            team2          toss_winner toss_decision  result  \
# 635  Royal Challengers Bangalore  Sunrisers Hyderabad           bat  normal
#
#      dl_applied               winner  win_by_runs  win_by_wickets  \
# 635           0  Sunrisers Hyderabad            8               0
#
#     player_of_match                  venue          umpire1       umpire2  \
# 635     BCJ Cutting  M Chinnaswamy Stadium  HDPK Dharmasena  BNJ Oxenford
#
#      umpire3
# 635      NaN

# %%
df.iloc[1:2,2:3]
# Out:
#    city
# 1  Pune

# %%
df.loc[[1,2,3],['id','season','city']] ### with columns name and row
# Out:
#    id  season    city
# 1   2    2017    Pune
# 2   3    2017  Rajkot
# 3   4    2017  Indore

# %%
df.loc[2,'city'] ### use the column name
# Out:
# 'Rajkot'

# %%
df.iloc[2,2] ## iloc used the index only
# Out:
# 'Rajkot'

# %% [markdown]
# ### groupby

# %%
df.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
df.groupby('season')['win_by_runs'].mean() ## series with single columns
# Out:
# season
# 2008    12.155172
# 2009    13.403509
# 2010    16.266667
# 2011    15.041096
# 2012    12.972973
# 2013    16.328947
# 2014    10.733333
# 2015    14.406780
# 2016    11.266667
# 2017    13.355932
# Name: win_by_runs, dtype: float64

# %%
multi_column=df.groupby(['season','city'])[['win_by_runs','win_by_wickets']].mean() ### dataframe for multiple columns
multi_column
# Out:
#                    win_by_runs  win_by_wickets
# season city
# 2008   Bangalore     22.285714        3.857143
#        Chandigarh    21.285714        2.714286
#        Chennai        6.857143        3.428571
#        Delhi          4.666667        3.000000
#        Hyderabad      6.857143        4.428571
# ...                        ...             ...
# 2017   Kanpur         0.000000        5.000000
#        Kolkata       15.428571        3.285714
#        Mumbai         5.500000        2.375000
#        Pune          22.571429        4.857143
#        Rajkot         9.400000        3.400000
#
# [106 rows x 2 columns]

# %%
### if you need "Flatten" the dataset use reset_index()
flaat=multi_column.reset_index()
flaat
# Out:
#      season        city  win_by_runs  win_by_wickets
# 0      2008   Bangalore    22.285714        3.857143
# 1      2008  Chandigarh    21.285714        2.714286
# 2      2008     Chennai     6.857143        3.428571
# 3      2008       Delhi     4.666667        3.000000
# 4      2008   Hyderabad     6.857143        4.428571
# ..      ...         ...          ...             ...
# 101    2017      Kanpur     0.000000        5.000000
# 102    2017     Kolkata    15.428571        3.285714
# 103    2017      Mumbai     5.500000        2.375000
# 104    2017        Pune    22.571429        4.857143
# 105    2017      Rajkot     9.400000        3.400000
#
# [106 rows x 4 columns]

# %%
### use ununique() value on padas series 
multi_col=df.groupby('season')['city'].nunique()
multi_col
# Out:
# season
# 2008     8
# 2009     8
# 2010    11
# 2011    11
# 2012    12
# 2013    12
# 2014    11
# 2015    12
# 2016    11
# 2017    10
# Name: city, dtype: int64

# %%
df['city'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0      Hyderabad
# 1           Pune
# 2         Rajkot
# 3         Indore
# 4      Bangalore
#          ...
# 631       Raipur
# 632    Bangalore
# 633        Delhi
# 634        Delhi
# 635    Bangalore
# Name: city, Length: 636, dtype: object>

# %%
mask=df['city']=='Hyderabad'
df[mask].shape[0]
# Out:
# 49

# %%
def get_city_match_count(city):
    mask=df['city']==city
    return df[mask].shape[0]

# %%
get_city_match_count('Hyderabad')
# Out:
# 49

# %%
mask1=df['city']=='Hyderabad'
mask2=df['date']>'2010-01-01'
df[mask1 & mask2].shape[0]
# Out:
# 42

# %%
df.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
#### value_counts functions used for series for frequecy count 
##its applicable for categorical data or categorial columns

# %%
df['winner'].value_counts().head()
# Out:
# Mumbai Indians                 92
# Chennai Super Kings            79
# Kolkata Knight Riders          77
# Royal Challengers Bangalore    73
# Kings XI Punjab                70
# Name: winner, dtype: int64

# %%
### plot
df['winner'].value_counts().head().plot(kind='bar')

# %%
print(df.head(1))
df['toss_decision'].value_counts().head()
# Out:
#    id  season       city        date                team1  \
# 0   1    2017  Hyderabad  2017-04-05  Sunrisers Hyderabad
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
#
#    result  dl_applied               winner  win_by_runs  win_by_wickets  \
# 0  normal           0  Sunrisers Hyderabad           35               0
#
#   player_of_match                                      venue      umpire1  \
# 0    Yuvraj Singh  Rajiv Gandhi International Stadium, Uppal  AY Dandekar
#
#     umpire2  umpire3
# 0  NJ Llong      NaN
# field    363
# bat      273
# Name: toss_decision, dtype: int64

# %%
type(df['season'].value_counts().head())
# Out:
# pandas.core.series.Series

# %%
#### series some operations 
myseries=df['winner'].value_counts()
myseries.index  ### -- index 
myseries.values
# Out:
# array([92, 79, 77, 73, 70, 63, 62, 42, 29, 13, 12, 10,  6,  5],
#       dtype=int64)

# %%
myseries=df['winner'].value_counts()
myseries
# Out:
# Mumbai Indians                 92
# Chennai Super Kings            79
# Kolkata Knight Riders          77
# Royal Challengers Bangalore    73
# Kings XI Punjab                70
# Rajasthan Royals               63
# Delhi Daredevils               62
# Sunrisers Hyderabad            42
# Deccan Chargers                29
# Gujarat Lions                  13
# Pune Warriors                  12
# Rising Pune Supergiant         10
# Kochi Tuskers Kerala            6
# Rising Pune Supergiants         5
# Name: winner, dtype: int64

# %%
myseries['Kings XI Punjab']
# Out:
# 70

# %%
df['team1'].value_counts().values
# Out:
# array([82, 77, 77, 70, 68, 63, 54, 46, 43, 20, 14,  8,  7,  7],
#       dtype=int64)

# %%
mydata=df['team2'].value_counts()+df['team1'].value_counts()
mydata['Mumbai Indians']
# Out:
# 157

# %%
##### Sort_value is used for series & dataframe both

# %%
mydata=df['team2'].value_counts()+df['team1'].value_counts()
mydata.sort_values(ascending=False)
# Out:
# Mumbai Indians                 157
# Royal Challengers Bangalore    152
# Kolkata Knight Riders          148
# Kings XI Punjab                148
# Delhi Daredevils               147
# Chennai Super Kings            131
# Rajasthan Royals               118
# Sunrisers Hyderabad             76
# Deccan Chargers                 75
# Pune Warriors                   46
# Gujarat Lions                   30
# Rising Pune Supergiant          16
# Rising Pune Supergiants         14
# Kochi Tuskers Kerala            14
# dtype: int64

# %%
df.head()
df['city'].sort_values(ascending=False)
# Out:
# 312    Visakhapatnam
# 618    Visakhapatnam
# 536    Visakhapatnam
# 315    Visakhapatnam
# 628    Visakhapatnam
#            ...
# 466              NaN
# 468              NaN
# 469              NaN
# 474              NaN
# 476              NaN
# Name: city, Length: 636, dtype: object

# %%
df.sort_values('city',ascending=False)
# Out:
#       id  season           city        date                        team1  \
# 312  313    2012  Visakhapatnam  2012-04-07          Chennai Super Kings
# 622  623    2016  Visakhapatnam  2016-05-15               Mumbai Indians
# 615  616    2016  Visakhapatnam  2016-05-10          Sunrisers Hyderabad
# 612  613    2016  Visakhapatnam  2016-05-08          Sunrisers Hyderabad
# 624  625    2016  Visakhapatnam  2016-05-17             Delhi Daredevils
# ..   ...     ...            ...         ...                          ...
# 466  467    2014            NaN  2014-04-23          Chennai Super Kings
# 468  469    2014            NaN  2014-04-25          Sunrisers Hyderabad
# 469  470    2014            NaN  2014-04-25               Mumbai Indians
# 474  475    2014            NaN  2014-04-28  Royal Challengers Bangalore
# 476  477    2014            NaN  2014-04-30          Sunrisers Hyderabad
#
#                        team2              toss_winner toss_decision  result  \
# ...

# %%
df.sort_values('city',ascending=False,inplace=True)

# %%
df
# Out:
#       id  season           city        date                        team1  \
# 312  313    2012  Visakhapatnam  2012-04-07          Chennai Super Kings
# 622  623    2016  Visakhapatnam  2016-05-15               Mumbai Indians
# 615  616    2016  Visakhapatnam  2016-05-10          Sunrisers Hyderabad
# 612  613    2016  Visakhapatnam  2016-05-08          Sunrisers Hyderabad
# 624  625    2016  Visakhapatnam  2016-05-17             Delhi Daredevils
# ..   ...     ...            ...         ...                          ...
# 466  467    2014            NaN  2014-04-23          Chennai Super Kings
# 468  469    2014            NaN  2014-04-25          Sunrisers Hyderabad
# 469  470    2014            NaN  2014-04-25               Mumbai Indians
# 474  475    2014            NaN  2014-04-28  Royal Challengers Bangalore
# 476  477    2014            NaN  2014-04-30          Sunrisers Hyderabad
#
#                        team2              toss_winner toss_decision  result  \
# ...

# %%
df.sort_values(['city','date'],ascending=[True,False])
# Out:
#       id  season       city        date                        team1  \
# 475  476    2014  Abu Dhabi  2014-04-29             Rajasthan Royals
# 471  472    2014  Abu Dhabi  2014-04-26              Kings XI Punjab
# 470  471    2014  Abu Dhabi  2014-04-26  Royal Challengers Bangalore
# 464  465    2014  Abu Dhabi  2014-04-21          Chennai Super Kings
# 460  461    2014  Abu Dhabi  2014-04-18          Sunrisers Hyderabad
# ..   ...     ...        ...         ...                          ...
# 468  469    2014        NaN  2014-04-25          Sunrisers Hyderabad
# 469  470    2014        NaN  2014-04-25               Mumbai Indians
# 466  467    2014        NaN  2014-04-23          Chennai Super Kings
# 461  462    2014        NaN  2014-04-19               Mumbai Indians
# 462  463    2014        NaN  2014-04-19        Kolkata Knight Riders
#
#                            team2                  toss_winner toss_decision  \
# ...

# %% [markdown]
# ##### drop_duplicates() method used to drop the duplicate values

# %%
data=df.drop_duplicates(subset=['city']) ### drop the duplicate city values

# %%
df.drop_duplicates(subset=['city']).shape
# Out:
# (31, 18)

# %%
df.shape
# Out:
# (636, 18)

# %%
df.drop_duplicates('season',keep='last')[['season','winner']].head()
# Out:
#      season                       winner
# 164    2009             Delhi Daredevils
# 44     2017        Kolkata Knight Riders
# 301    2011  Royal Challengers Bangalore
# 316    2012        Kolkata Knight Riders
# 451    2013  Royal Challengers Bangalore

# %%
df.drop_duplicates('season',keep='last')[['season','winner']].sort_values('season')
# Out:
#      season                       winner
# 89     2008               Mumbai Indians
# 164    2009             Delhi Daredevils
# 179    2010             Delhi Daredevils
# 301    2011  Royal Challengers Bangalore
# 316    2012        Kolkata Knight Riders
# 451    2013  Royal Challengers Bangalore
# 476    2014          Sunrisers Hyderabad
# 525    2015             Rajasthan Royals
# 635    2016          Sunrisers Hyderabad
# 44     2017        Kolkata Knight Riders
