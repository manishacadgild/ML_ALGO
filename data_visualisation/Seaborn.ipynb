# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data=sns.load_dataset('tips')

# %%
data.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
data['time'].unique()
# Out:
# [Dinner, Lunch]
# Categories (2, object): [Dinner, Lunch]

# %%
data.info()
print(data.shape)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.3 KB
# (244, 7)

# %% [markdown]
# #### plot a scatter plot for total_bill & tip

# %%
sns.relplot(x='total_bill',y='tip',kind='scatter',data=data)

# %%
sns.relplot(x='total_bill',y='tip',hue='smoker',data=data)

# %% [markdown]
# ##### Style parameter

# %%
sns.relplot(x='total_bill',y='tip',hue='smoker',style='sex',data=data)

# %% [markdown]
# #### Size parameter

# %%
sns.relplot(x='total_bill',y='tip',hue='smoker',style='sex',size='size',sizes=(15,200),data=data)

# %% [markdown]
# #### using scaterplot

# %%
sns.scatterplot(x='total_bill',y='tip',hue='smoker',data=data)

# %% [markdown]
# #### Categorical Scatterlot

# %%
data.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
### X-axis -Categorial data
### Y-axis -Numerial data
data['day'].value_counts(sort=True)
index = pd.Index([3, 1, 2, 3, 4, np.nan])
index.dropna()
# Out:
# Float64Index([3.0, 1.0, 2.0, 3.0, 4.0], dtype='float64')

# %%
sns.catplot(x='day',y='tip',kind='swarm',data=data)

# %%
sns.swarmplot(x='day',y='tip',data=data)

# %%
data.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
data.isnull().sum().sum()
# Out:
# 0

# %%
### univariate 
#sns.boxplot(data['tip'])

sns.boxplot(data['total_bill'])

# %%
sns.catplot(x='day',y='tip',kind='box',data=data)

# %%
sns.catplot(x='day',y='total_bill',hue='sex',kind='box',data=data)
